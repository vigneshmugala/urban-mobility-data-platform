# %%
csv_df = (spark.read
    .option('header', 'true')
    .option('inferSchema', 'true')
    .csv('/Volumes/urban-mobility-data-platform-dev/source/data/taxi_zone_lookup.csv')
)

# %%
csv_df.display()

# %%
csv_df.write.mode("overwrite").saveAsTable("`urban-mobility-data-platform-dev`.bronze.taxi_lookup_table")

# %%
# %sql
SELECT * FROM `urban-mobility-data-platform-dev`.bronze.taxi_lookup_table;

# %%
# %sql
CREATE TABLE IF NOT EXISTS `urban-mobility-data-platform-dev`.source.taxi_zone_lookup 
USING CSV 
OPTIONS(
     path '/Volumes/urban-mobility-data-platform-dev/source/data/taxi_zone_lookup.csv',
     header 'true',
     inferSchema 'true'
);
