# %%
# %sql
SELECT
    LocationID,
    Borough,
    Zone,
    service_zone,
    dbt_valid_from,
    dbt_valid_to
FROM `urban-mobility-data-platform-dev`.silver.taxi_zone_history
WHERE LocationID = 161;

# %%
# %sql
ALTER TABLE `urban-mobility-data-platform-dev`.silver.taxi_zone_history  SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name')

# %%
# %sql
ALTER TABLE  `urban-mobility-data-platform-dev`.silver.taxi_zone_history
RENAME COLUMN dbt_valid_from TO valid_from

# %%
# %sql
ALTER TABLE  `urban-mobility-data-platform-dev`.silver.taxi_zone_history
RENAME COLUMN dbt_valid_to TO valid_to

# %%
# %sql
ALTER TABLE  `urban-mobility-data-platform-dev`.silver.taxi_zone_history
RENAME COLUMN valid_to TO valid_till

# %%
# %sql
DESC `urban-mobility-data-platform-dev`.silver.taxi_zone_history

# %%
# %sql
DESC `urban-mobility-data-platform-dev`.silver.taxi_zone_history

# %%
# %sql
SELECT * from `urban-mobility-data-platform-dev`.silver.taxi_zone_history where LocationID = 69

# %%
# %sql
UPDATE `urban-mobility-data-platform-dev`.bronze.taxi_lookup_test  set Borough = 'HYDERABAD', Zone = 'Ramanthapur' where LocationID = 69

# %%
# %sql
SELECT * from `urban-mobility-data-platform-dev`.silver.taxi_zone_history where LocationID = 69

# %%
# %sql
UPDATE `urban-mobility-data-platform-dev`.bronze.taxi_lookup_test  set Borough = 'mama', service_zone = 'bruh' where LocationID = 69

# %%
# %sql
SELECT * from `urban-mobility-data-platform-dev`.silver.taxi_zone_history where LocationID = 69
