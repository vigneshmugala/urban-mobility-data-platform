# %%
# %sql
SHOW TABLES IN `urban-mobility-data-platform-dev`.bronze

# %%
# %sql
DESC `urban-mobility-data-platform-dev`.bronze.yellow_trips_raw

# %%
# %sql
SELECT
    tpep_pickup_datetime,
    typeof(tpep_pickup_datetime) AS data_type,
    HOUR(tpep_pickup_datetime) AS pickup_hour,
    EXTRACT(HOUR FROM tpep_pickup_datetime) AS extracted_hour
FROM `urban-mobility-data-platform-dev`.silver.stg_yellow_trips
WHERE tpep_pickup_datetime > '2026-01-01T01:00:00'
LIMIT 20;

# %%
# %sql
SELECT current_timezone();

# %%
# %sql
select count(*) from `urban-mobility-data-platform-dev`.bronze.yellow_trips_raw;

# %%
# %sql
select count(*) from `urban-mobility-data-platform-dev`.silver.int_yellow_trip_cleaned
