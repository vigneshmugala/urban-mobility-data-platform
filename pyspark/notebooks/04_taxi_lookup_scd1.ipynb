# %%
# %sql
CREATE TABLE `urban-mobility-data-platform-dev`.silver.taxi_lookup_current
FROM `urban-mobility-data-platform-dev`.bronze.taxi_lookup_table

# %%
# %sql
SELECT count(*) from `urban-mobility-data-platform-dev`.bronze.taxi_lookup_table;

# %%
# %sql
SELECT count(*) from `urban-mobility-data-platform-dev`.silver.taxi_lookup_current;

# %%
# %sql
SELECT * from `urban-mobility-data-platform-dev`.silver.taxi_lookup_current;

# %%
# %sql
CREATE TABLE `urban-mobility-data-platform-dev`.bronze.taxi_lookup_TEST
FROM `urban-mobility-data-platform-dev`.bronze.taxi_lookup_table

# %%
## incremental update testng

# %%
# %sql
SELECT * FROM `urban-mobility-data-platform-dev`.bronze.taxi_lookup_test where LocationID = 69

# %%
# %sql
SELECT * from `urban-mobility-data-platform-dev`.silver.taxi_lookup_current where LocationID = 69

# %%
# %sql
UPDATE `urban-mobility-data-platform-dev`.bronze.taxi_lookup_test  set Borough = 'Delhi' where LocationID = 69

# %%
# %sql
SELECT * FROM `urban-mobility-data-platform-dev`.bronze.taxi_lookup_test where LocationID = 69

# %%
# %sql
SELECT * from `urban-mobility-data-platform-dev`.silver.taxi_lookup_current where LocationID = 69

# %%
# %sql
SELECT * from `urban-mobility-data-platform-dev`.silver.taxi_lookup_current where LocationID = 69
